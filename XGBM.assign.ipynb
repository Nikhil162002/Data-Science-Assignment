# %%
import pandas as pd
import numpy  as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Titanic_train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].isna().sum()
# Out:
# 177

# %%
df['Age'].fillna(29, inplace=True)

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df['Embarked'].isna().sum()
# Out:
# 2

# %%
df['Embarked'].fillna('S', inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.drop(columns= ['PassengerId','Name','Cabin','Ticket'], inplace=True)

# we don't have need these columns because in cabin there is 70% null values so we drop it

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.560236    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.005010    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
def outlier_detection(data,column):
  q1 = data[column].quantile(0.25)
  q3 = data[column].quantile(0.75)
  iqr = q3- q1
  upper_ext = q3 + iqr*1.5
  lower_ext = q1 - iqr*1.5
  return lower_ext,upper_ext

# %%
outlier_detection(df,'Age')
# Out:
# (2.5, 54.5)

# %%
df.loc[df['Age']>54.5,'Age']=54.5

# %%
df.loc[df['Age']<2.5,'Age']=2.5

# %%
outlier_detection(df,'Fare')
# Out:
# (-26.724, 65.6344)

# %%
df.loc[df['Fare']>65.63,'Fare']=65.63

# %%
df.boxplot()

# in Sibsp, PArch  column we show outliers but these are near to zero so we cannot work on it
# Out:
# <Axes: >

# %%
sns.scatterplot(x='Age', y = 'Fare', hue = 'Survived', data = df)
plt.show()

# %%
# Example: Bar plot of survival rate by 'Sex'
sns.barplot(x='Sex', y='Survived', data=df)
plt.show()

# %%
# Example: Bar plot of survival rate by 'Pclass'
sns.barplot(x='Pclass', y='Survived', data=df)
plt.show()

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch    Fare Embarked
# 0         0       3    male  22.0      1      0   7.250        S
# 1         1       1  female  38.0      1      0  65.630        C
# 2         1       3  female  26.0      0      0   7.925        S
# 3         1       1  female  35.0      1      0  53.100        S
# 4         0       3    male  35.0      0      0   8.050        S

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Sex'] = le.fit_transform(df['Sex'])

# %%
df['Embarked']= le.fit_transform(df['Embarked'])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch    Fare  Embarked
# 0         0       3    1  22.0      1      0   7.250         2
# 1         1       1    0  38.0      1      0  65.630         0
# 2         1       3    0  26.0      0      0   7.925         2
# 3         1       1    0  35.0      1      0  53.100         2
# 4         0       3    1  35.0      0      0   8.050         2

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex           int64
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked      int64
# dtype: object

# %%
# we apply standardscaler method on the data set we shown that there is huge gap between the values of features

from sklearn.preprocessing import StandardScaler

# %%
# Select numerical features for scaling (e.g., 'Age', 'Fare')
numerical_features = ['Age', 'Fare']

# Create a StandardScaler object
scaler = StandardScaler()

# Fit the scaler to your numerical features and transform them
df[numerical_features] = scaler.fit_transform(df[numerical_features])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0         0       3    1 -0.600420      1      0 -0.820571         2
# 1         1       1    0  0.726854      1      0  2.031552         0
# 2         1       3    0 -0.268602      0      0 -0.787594         2
# 3         1       1    0  0.477990      1      0  1.419405         2
# 4         0       3    1  0.477990      0      0 -0.781488         2

# %% [markdown]
# **Building and Evaluating LightGBM and XGBoost Models**

# %%
from sklearn.model_selection import train_test_split

x = df.drop('Survived',axis =1)
y = df['Survived']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)

# %%
import lightgbm as lgb
import xgboost as xgb

# Create LightGBM model
lgb_model = lgb.LGBMClassifier(random_state=0)

# Create XGBoost model
xgb_model = xgb.XGBClassifier(random_state=0)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Train LightGBM model
lgb_model.fit(x_train, y_train)
lgb_predictions = lgb_model.predict(x_test)

# Evaluate LightGBM model
lgb_accuracy = accuracy_score(y_test, lgb_predictions)
# ... (calculate other metrics similarly)

# Train XGBoost model
xgb_model.fit(x_train, y_train)
xgb_predictions = xgb_model.predict(x_test)

# Evaluate XGBoost model
xgb_accuracy = accuracy_score(y_test, xgb_predictions)
# ... (calculate other metrics similarly)

# Print the evaluation results
print("LightGBM Accuracy:", lgb_accuracy)
# ... (print other metrics)
print("XGBoost Accuracy:", xgb_accuracy)
# ... (print other metrics)
# Out:
# [LightGBM] [Info] Number of positive: 273, number of negative: 439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000566 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 169
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383427 -> initscore=-0.475028
# [LightGBM] [Info] Start training from score -0.475028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# **Optimizing Models with Cross-Validation and Hyperparameter Tuning**

# %%
from sklearn.model_selection import cross_val_score

# %%
# Perform 5-fold cross-validation for LightGBM
lgb_scores = cross_val_score(lgb_model, x, y, cv=5, scoring='accuracy')  # Use desired scoring metric
print("LightGBM Cross-Validation Scores:", lgb_scores)
print("LightGBM Mean Accuracy:", lgb_scores.mean())

# Perform 5-fold cross-validation for XGBoost
xgb_scores = cross_val_score(xgb_model, x, y, cv=5, scoring='accuracy')  # Use desired scoring metric
print("XGBoost Cross-Validation Scores:", xgb_scores)
print("XGBoost Mean Accuracy:", xgb_scores.mean())
# Out:
# [LightGBM] [Info] Number of positive: 273, number of negative: 439
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 171
# [LightGBM] [Info] Number of data points in the train set: 712, number of used features: 7
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.383427 -> initscore=-0.475028
# [LightGBM] [Info] Start training from score -0.475028
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Hyperparameter Tuning (using GridSearchCV):

# %%
from sklearn.model_selection import GridSearchCV

# Define hyperparameter grids for LightGBM and XGBoost
lgb_param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.05, 0.01],
    # ... other LightGBM hyperparameters
}

xgb_param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.1, 0.05, 0.01],
    # ... other XGBoost hyperparameters
}

# Create GridSearchCV objects
lgb_grid = GridSearchCV(lgb_model, lgb_param_grid, cv=5, scoring='accuracy')  # Use desired scoring metric
xgb_grid = GridSearchCV(xgb_model, xgb_param_grid, cv=5, scoring='accuracy')  # Use desired scoring metric

# Fit the GridSearchCV objects to find the best hyperparameters
lgb_grid.fit(x_train, y_train)
xgb_grid.fit(x_train, y_train)

# Get the best models and their scores
best_lgb_model = lgb_grid.best_estimator_
best_xgb_model = xgb_grid.best_estimator_

print("Best LightGBM Parameters:", lgb_grid.best_params_)
print("Best LightGBM Score:", lgb_grid.best_score_)
print("Best XGBoost Parameters:", xgb_grid.best_params_)
print("Best XGBoost Score:", xgb_grid.best_score_)
# Out:
# Streaming output truncated to the last 5000 lines.
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# By combining cross-validation and hyperparameter tuning, you can significantly improve the performance and generalization ability of your LightGBM and XGBoost models.

# %% [markdown]
# Comparative Analysis of LightGBM and XGBoost

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# ... (previous code for training and evaluation)

# Compare accuracy
print("LightGBM Accuracy:", lgb_accuracy)
print("XGBoost Accuracy:", xgb_accuracy)

# Compare precision
print("LightGBM Precision:", precision_score(y_test, lgb_predictions))
print("XGBoost Precision:", precision_score(y_test, xgb_predictions))

# Compare recall
print("LightGBM Recall:", recall_score(y_test, lgb_predictions))
print("XGBoost Recall:", recall_score(y_test, xgb_predictions))

# Compare F1-score
print("LightGBM F1-score:", f1_score(y_test, lgb_predictions))
print("XGBoost F1-score:", f1_score(y_test, xgb_predictions))
# Out:
# LightGBM Accuracy: 0.8435754189944135
# XGBoost Accuracy: 0.8547486033519553
# LightGBM Precision: 0.8596491228070176
# XGBoost Precision: 0.8524590163934426
# LightGBM Recall: 0.7101449275362319
# XGBoost Recall: 0.7536231884057971
# LightGBM F1-score: 0.7777777777777778
# XGBoost F1-score: 0.8

# %%
import matplotlib.pyplot as plt
import numpy as np

models = ['LightGBM', 'XGBoost']
accuracies = [lgb_accuracy, xgb_accuracy]

plt.bar(models, accuracies)
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison of LightGBM and XGBoost')
plt.show()
