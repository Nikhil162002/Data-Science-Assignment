# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/glass.csv')
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0   1.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0   1.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0   1.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0   1.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0   1.0
# ..       ...    ...   ...   ...    ...   ...   ...  ...  ...   ...
# 994      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 995      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 996      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 997      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
# 998      NaN    NaN   NaN   NaN    NaN   NaN   NaN  NaN  NaN   NaN
#
# [999 rows x 10 columns]

# %%
df.shape
# Out:
# (999, 10)

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    float64
# dtypes: float64(10)
# memory usage: 78.2 KB

# %%
df.isna().sum()
# Out:
# RI      785
# Na      785
# Mg      785
# Al      785
# Si      785
# K       785
# Ca      785
# Ba      785
# Fe      785
# Type    785
# dtype: int64

# %%
df = df.dropna(how='all')

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0   1.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0   1.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0   1.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0   1.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0   1.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0   7.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0   7.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0   7.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0   7.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0   7.0
#
# [214 rows x 10 columns]

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)
# Out:
# <ipython-input-36-16cdb8520be8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# RI      float64
# Na      float64
# Mg      float64
# Al      float64
# Si      float64
# K       float64
# Ca      float64
# Ba      float64
# Fe      float64
# Type    float64
# dtype: object

# %%
df.hist()
plt.tight_layout()

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
def outlier_detection(data,column):
  q1 = data[column].quantile(0.25)
  q3 = data[column].quantile(0.75)
  iqr = q3-q1

  lower_ext= q1-iqr*1.5
  upper_ext = q3+iqr*1.5
  return lower_ext,upper_ext

# %%
outlier_detection(df,'RI')
# Out:
# (1.5125750000000002, 1.5230949999999999)

# %%
plt.boxplot(df['RI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef484816140>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef4848177c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef484815f60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef4848147f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef484d9bbb0>],
#  'means': []}

# %%
df.loc[df['RI']<1.512,'RI']=1.512
# Out:
# <ipython-input-42-5f3bceb46282>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['RI']<1.512,'RI']=1.512

# %%
df.loc[df['RI']>1.523,'RI']=1.523
# Out:
# <ipython-input-43-dff9c528d729>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['RI']>1.523,'RI']=1.523

# %%
outlier_detection(df,'Na')
# Out:
# (11.535, 15.175)

# %%
df.loc[df['Na']>15.175,'Na']=15.175
# Out:
# <ipython-input-45-e3c91b9fedce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Na']>15.175,'Na']=15.175

# %%
df.loc[df['Na']<11.535,'Na']=11.535
# Out:
# <ipython-input-46-0ab435b91ff0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Na']<11.535,'Na']=11.535

# %%
plt.boxplot(df['Na'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef47f2a6ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef47f2a7220>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef47f2a6a40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef47f2a7760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef47f2a7a00>],
#  'means': []}

# %%
outlier_detection(df,'Al')
# Out:
# (0.53, 2.29)

# %%
df.loc[df['Al']>2.29,'Al']=2.29
# Out:
# <ipython-input-52-6d9d872c7529>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Al']>2.29,'Al']=2.29

# %%
df.loc[df['Al']<0.53,'Al']=0.53
# Out:
# <ipython-input-53-aa6c5979c7ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Al']<0.53,'Al']=0.53

# %%
plt.boxplot(df['Al'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ef47f30ee90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7ef47f30f3d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7ef47f30ebf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ef47f30f910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ef47f30fbb0>],
#  'means': []}

# %%
outlier_detection(df,'Si')
# Out:
# (71.065, 74.305)

# %%
df.loc[df['Si']>74.305,'Si']=74.305
# Out:
# <ipython-input-56-c5ce311d5081>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Si']>74.305,'Si']=74.305

# %%
df.loc[df['Si']<71.065,'Si']=71.065
# Out:
# <ipython-input-57-01e24774eadd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Si']<71.065,'Si']=71.065

# %%
outlier_detection(df,'K')
# Out:
# (-0.59, 1.33)

# %%
df.loc[df['K']>1.33,'K']=1.33
# Out:
# <ipython-input-59-68d304b8b8d5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['K']>1.33,'K']=1.33

# %%
outlier_detection(df,'Ca')
# Out:
# (6.875, 10.515)

# %%
df.loc[df['Ca']>10.515,'Ca']=10.515
# Out:
# <ipython-input-61-cc1d3b108559>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Ca']>10.515,'Ca']=10.515

# %%
df.loc[df['Ca']<6.875,'Ca']=6.875
# Out:
# <ipython-input-62-e89047d5aaf4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['Ca']<6.875,'Ca']=6.875

# %%
outlier_detection(df,'Ba')
# Out:
# (0.0, 0.0)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
sns.pairplot(df,hue = 'Type')

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# we have found that there is a realation between Ri and Ca column

# %%
from sklearn.preprocessing import StandardScaler

# %%
numerical_col = ['RI','Na','Mg','Al','Si','K','Ca','Ba','Fe']

# %%
scaler = StandardScaler()

df[numerical_col] = scaler.fit_transform(df[numerical_col])
# Out:
# <ipython-input-72-e7b1db52e88a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[numerical_col] = scaler.fit_transform(df[numerical_col])

# %%
df
# Out:
#            RI        Na        Mg        Al        Si         K        Ca  \
# 0    1.219148  0.322680  1.257238 -0.773927 -1.361078 -1.253536 -0.044419
# 1   -0.220922  0.660556  0.639311 -0.154741  0.086641  0.124799 -1.115733
# 2   -0.826599  0.174014  0.604596  0.273927  0.482859 -0.170559 -1.173956
# 3   -0.199745 -0.258467  0.701798 -0.321445 -0.096228  0.420156 -0.661589
# 4   -0.301397 -0.177377  0.653197 -0.440519  0.620012  0.354521 -0.836260
# ..        ...       ...       ...       ...       ...       ...       ...
# 209 -0.805421  0.998432 -1.860172  2.060042 -0.096228 -1.187901  0.456303
# 210 -0.542820  2.052606 -1.860172  1.345596  0.589533 -1.450441 -0.451984
# 211  1.066670  1.295764 -1.860172  1.417041  1.138143 -1.450441 -0.405405
# 212 -0.686827  1.322794 -1.860172  1.226522  1.427687 -1.450441 -0.358827
# 213 -0.432697  1.120068 -1.860172  1.559930  1.046708 -1.450441 -0.195801
#
#            Ba        Fe  Type
# 0   -0.353808 -0.588301   1.0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop('Type', axis=1)
y=df['Type']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_classifier= RandomForestClassifier(n_estimators = 100, random_state = 0)


rf_classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
y_pred = rf_classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.7441860465116279

# %%
precision = precision_score(y_test,y_pred, average = 'micro')
print(precision)
# Out:
# 0.7441860465116279

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=0)
rf_classifier.fit(x_train, y_train)
y_pred_rf = rf_classifier.predict(x_test)

# %%
# Bagging Classifier (using Decision Tree as base estimator)
bagging_classifier = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100, random_state=0)
bagging_classifier.fit(x_train, y_train)
y_pred_bagging = bagging_classifier.predict(x_test)

# %%
result = cross_val_score(bagging_classifier,x,y,cv=KFold(n_splits=10))

# %%
result
# Out:
# array([0.45454545, 0.77272727, 0.59090909, 0.76190476, 0.23809524,
#        0.47619048, 0.66666667, 0.0952381 , 0.23809524, 0.9047619 ])

# %%
result.mean()
# Out:
# 0.51991341991342

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
boosting_classifier = AdaBoostClassifier(n_estimators=50, random_state=0)
boosting_classifier.fit(x_train, y_train)
y_pred_boosting = boosting_classifier.predict(x_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
result1 = cross_val_score(boosting_classifier,x,y,cv= KFold(n_splits=10, random_state=0,shuffle=True))
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# ...

# %%
result1
# Out:
# array([0.36363636, 0.54545455, 0.54545455, 0.47619048, 0.23809524,
#        0.42857143, 0.47619048, 0.52380952, 0.42857143, 0.38095238])

# %%
result1.mean()
# Out:
# 0.44069264069264075

# %%
boosting_result = result.mean()
bagging_result = result1.mean()

print(boosting_result)
print(bagging_result)
# Out:
# 0.51991341991342
# 0.44069264069264075

# %% [markdown]
# In this scenerio boosting classifier gives better result as compare to bagging classifier

# %% [markdown]
# Additional Notes
#
# Boosting : Boosting involves training base estimators sequentially, where each subsequent estimator focuses on correcting the errors made by the previous ones.
#
# Bagging : Bagging involves creating multiple subsets of the original dataset by randomly sampling data points with replacement (bootstrapping).
#
#
# 2. Handling Imbalance in the Data
#
# Data imbalance occurs when one class has significantly more samples than another. This can lead to biased models that perform poorly on the minority class.
